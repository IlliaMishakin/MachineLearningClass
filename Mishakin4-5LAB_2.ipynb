# %% [markdown]
# Мішакін Ілля 4-5

# %%
import pandas as pd

# %%
df = pd.read_html('https://uk.wikipedia.org/wiki/%D0%A1%D0%B5%D1%80%D0%B5%D0%B4%D0%BD%D1%8F_%D0%B7%D0%B0%D1%80%D0%BE%D0%B1%D1%96%D1%82%D0%BD%D0%B0_%D0%BF%D0%BB%D0%B0%D1%82%D0%B0_%D0%B2_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D1%96', header=0)[2]
df.head()
# Out:
#     Рік В національнійвалюті В доларах США  \
# 0  1992             5832,88▲        28,04▼
# 1  1993              163533▲        36,03▲
# 2  1994             1426343▲        44,99▲
# 3  1995             7304000▲        49,53▲
# 4  1996              125,23▼        68,45▲
#
#   Кількість кгхліба[20] на середнюзарплату  \
# 0                                 1015,67▲
# 1                                  430,42▼
# 2                                  372,76▼
# 3                                  201,76▼
# 4                                  198,62▼
#
#   Кількість БігМаківна середню зарплату
# 0                                     —
# 1                                     —
# 2                                     —
# 3                                     —
# 4                                     —

# %%
df.shape
# Out:
# (32, 5)

# %%
total_years = df['Рік'].nunique()
print("Загальна кількість років:", total_years)
# Out:
# Загальна кількість років: 32

# %%
total_months = total_years * 12
print("Загальна кількість місяців:", total_months)
# Out:
# Загальна кількість місяців: 384

# %%
df.replace("—", pd.NA, inplace=True)
df
# Out:
#       Рік В національнійвалюті В доларах США  \
# 0    1992             5832,88▲        28,04▼
# 1    1993              163533▲        36,03▲
# 2    1994             1426343▲        44,99▲
# 3    1995             7304000▲        49,53▲
# 4    1996              125,23▼        68,45▲
# 5    1997              143,09▲        76,86▲
# 6    1998              152,83▲        62,39▼
# 7    1999              177,39▲        42,95▼
# 8    2000              231,04▲        42,47▼
# 9    2001              311,62▲        58,01▲
# 10   2002              375,98▲        70,59▲
# 11   2003              462,58▲        86,74▲
# 12   2004              590,53▲       111,02▲
# 13   2005              806,14▲       157,30▲
# 14   2006             1042,88▲       206,51▲
# 15   2007             1352,75▲       267,87▲
# 16   2008             1808,92▲       343,43▲
# 17   2009             1909,25▲       245,05▼
# 18   2010             2246,75▲       283,12▲
# 19   2011             2639,17▲       331,24▲
# 20   2012             3031,92▲       379,42▲
# 21   2013             3273,82▲       409,59▲
# 22   2014             3474,75▲       292,32▼
# 23   2015             4207,33▲       162,60▼
# 24   2016             5187,33▲       203,02▲
# 25   2017             7105,42▲       267,16▲
# 26   2018             8867,33▲       325,99▲
# 27   2019            10503,75▲       406,40▲
# 28   2020            11596,60▲       430,21▲
# 29   2021            14017,80▲       514,41▲
# 30  2022*            13376,21▼       380,00▼
# 31  2023*            13768,40▲       358,72▼
#
#    Кількість кгхліба[20] на середнюзарплату  \
# 0                                  1015,67▲
# 1                                   430,42▼
# 2                                   372,76▼
# 3                                   201,76▼
# 4                                   198,62▼
# 5                                   211,13▲
# 6                                   177,69▼
# 7                                   180,68▲
# 8                                   117,51▼
# 9                                   153,57▲
# 10                                  213,84▲
# 11                                  276,27▲
# 12                                  276,06▼
# 13                                  332,05▲
# 14                                  441,28▲
# 15                                  498,66▲
# 16                                  585,00▲
# 17                                  497,02▼
# 18                                  527,82▲
# 19                                  564,37▲
# 20                                  585,38▲
# 21                                  625,00▲
# 22                                  642,39▲
# 23                                  517,22▼
# 24                                  441,05▼
# 25                                  450,35▲
# 26                                  497,05▲
# 27                                  528,09▲
# 28                                  549,08▲
# 29                                  560,03▲
# 30                                  409,57▼
# 31                                  387,62▼
#
#    Кількість БігМаківна середню зарплату
# 0                                   <NA>
# 1                                   <NA>
# 2                                   <NA>
# 3                                   <NA>
# 4                                   <NA>
# 5                                 20[21]
# 6                                   н.д.
# 7                                24▲[22]
# 8                                   н.д.
# 9                                50▲[23]
# 10                                  н.д.
# 11                                  н.д.
# 12                                   81▲
# 13                                  111▲
# 14                                  123▲
# 15                                  146▲
# 16                                  164▲
# 17                                  136▼
# 18                                  155▲
# 19                                  160▲
# 20                                  202▲
# 21                                  172▼
# 22                                  182▲
# 23                                  124▼
# 24                                  133▲
# 25                                  161▲
# 26                                  177▲
# 27                                  184▲
# 28                                  187▲
# 29                                  216▲
# 30                                  132▼
# 31                                  131▼

# %%
column_types = df.dtypes
column_types
# Out:
# Рік                                         object
# В національнійвалюті                        object
# Кількість кгхліба[20] на середнюзарплату    object
# dtype: object

# %%
df = df.drop(df.columns[-1], axis=1)  
df = df.drop(df.columns[-2], axis=1)  

df.head()
# Out:
#     Рік В національнійвалюті Кількість кгхліба[20] на середнюзарплату
# 0  1992             5832,88▲                                 1015,67▲
# 1  1993              163533▲                                  430,42▼
# 2  1994             1426343▲                                  372,76▼
# 3  1995             7304000▲                                  201,76▼
# 4  1996              125,23▼                                  198,62▼

# %%
missing_values = df.isnull().sum()
total_values = len(df)
missing_ratio = missing_values / total_values

missing_ratio
# Out:
# Рік                                         0.0625
# В національнійвалюті                        1.0000
# Кількість кгхліба[20] на середнюзарплату    1.0000
# dtype: float64
